# %% [markdown]
# # ML App to Build a Chatbot
#
# ## Introduction:
#
# This project aims to cover the process on how to build a chatbot. Generally, a chatbot can conduct a conversation or conversations through auditory or textual methods. These programmes are often designed to convincingly simulate or mimic a human conversational partner. Usually, they are far short of being able to pass the Turing test. Chatbots are typically used in dialog systems for various practical purposes such as customer service or information acquisition. Some chatbots do utilise sophisticated natural language processing (NLP) systems, however there are many simpler ones scan for keywords within the input, then pull a reply accordingly with the most matching keywords, or the most similar wording pattern, from a database.
#
# ## Breakdown for this Project:
# - The Turing Test
# - History of Chatbots
# - Design of Chatbots
# - Building a Chatbot
#
# ## 1 The Turing Test:
#
# “The Turing Test” refers to a proposal made by Turing (1950) as a way of dealing with the question whether machines can think, or rather think intelligently like a human.
#
# Turing describes the following kind of game hence it is called "the imitation game". Suppose that we have a person, a machine, and an interrogator. The interrogator is in a room that is separated from the other person and the machine. The objective would be for the interrogator to determine which of the other two is the person, and which is the machine. The interrogator knows the other person and the machine by the labels ‘X’ and ‘Y’—but, at least at the beginning of the game, does not know which of the other person and the machine is ‘X’—and at the end of the game says either ‘X is the person and Y is the machine’ or ‘X is the machine and Y is the person’. The interrogator is allowed to put questions to the person and the machine of the following kind: “Will X please tell me whether X plays chess?” Whichever of the machine and the other person is X must answer questions that are addressed to X. The object of the machine is to try to cause the interrogator to mistakenly conclude that the machine is the other person; the object of the other person is to try to help the interrogator to correctly identify the machine. - Taken from the source (1)
#
# Source:
# - (1) https://plato.stanford.edu/entries/turing-test/
#
# ## 2 History of Chatbots:
#
# __ELIZA:__ It was considered to be the first chatbot in the history of Computer Science. ELIZA was developed by Joseph Weizenbaum at Massachusetts Institute of Technology (MIT). It was in 1994 that the term ‘Chatterbot” was coined. ELIZA operates by recognising key words or phrases from the input and proceeds to reproduce a response from its pre-programmed responses according to the keywords. For instance, if a human says that ‘My mother cooks good food’. ELIZA would pick up the word ‘mother’, and respond by asking an open- ended question ‘Tell me more about your family’. This created an illusion of understanding and simulates an interaction with a real human being though the process was a mechanised one.
#
# __ALICE:__ It was developed in 1995 by Richard Wallace. ALICE chatbot was able to use natural language processing (NLP), which allowed for more sophisticated conversation. It was revolutionary, though, for being open-source. Developers could use AIML (artificial intelligence markup language) to create their own chatbots powered by ALICE.
#
# __JABBERWACKY:__ Jabberwacky is a chatterbot created by British programmer Rollo Carpenter. Its stated aim is to “simulate natural human chat in an interesting, entertaining and humorous manner”. It is an early attempt at creating an artificial intelligence through human interaction. The stated purpose was to create an artificial intelligence that would be capable of passing the Turing Test. It is designed to mimic human interaction and to carry out conversations with users. It is not designed to carry out any other functions. Recent developments do allow a more scripted, controlled approach to sit atop the general conversational AI, aiming to bring together the best of both approaches, and usage in the fields of sales and marketing is underway. The ultimate intention is that the program move from a text based system to be wholly voice operated-learning directly from sound and other sensory inputs. JABBERWACKY's creator believes that it can be incorporated into objects around the home such as robots or talking pets, intending both to be useful and entertaining, keeping people company.
#
# __MITSUKU:__ Mitsuku is a chatbot created from AIMLtechnology by Steve Worswick. It claims to be an 18-year-old female chatbot from Leeds, England. It contains all of Alice’s AIML files, with many additions from user generated conversations, and is always a work in progress. Her intelligence includes the ability to reason with specific objects. For example, if someone asks “Can you eat a house?”, Mitsuku looks up the properties for “house”. Finds the value of “made_from” is set to “brick” and replies “no”, as a house is not edible. She can play games and do magic tricks at the user’s request. In 2015 she conversed, on average, in excess of a quarter of a million times daily.
#
# Source: https://chatbotslife.com/a-brief-history-of-chatbots-d5a8689cf52f
#
#
# ## 3 Design of Chatbots:
#
# Taking the example of ELIZA chatbot which consist of around 200 lines of code and the Python NLTK implementation is equally short which can be seen here: http://www.nltk.org/_modules/nltk/chat/eliza.html or the sample diagram below:

# %%
import os
from IPython.display import Image
from IPython.core.display import Image, display ,HTML

# %%
# Set up the working directory for the images:
image_folderName = 'Description Images'
image_path = os.path.abspath(image_folderName) + '/'

# %%
# ELIZA chatbot sample code: 
display(Image(image_path+'ELIZA Python NLTK implementation.png', width=500, unconfined=True))
print('Image ref -> http://www.nltk.org/_modules/nltk/chat/eliza.html')
# Out:
# Image ref -> http://www.nltk.org/_modules/nltk/chat/eliza.html

# %% [markdown]
# From the sample, it can be seen that the input text was parsed before being matched against a series of regular expressions. After a match was found, it proceeds to get a randomised response to be returned. The design is simple but still able to make people believe that ELIZA was a human.
#
# #### This is then followed by, How about more advance methoed of creating a Chatbot?
#
# The most common types of chatbot encountered aren't machine learning based but rather are known as retrieval-based models. This is where the responses of these bots are predefined to the question or its context. The architecture for these bots are called Artificial Intelligence Markup Language (AIML). AIML is a XML-based schema that represents the bot's interactiong for a given user input.
#
# #### Another interesting method is published by Oriol Vinyas and Quoc Le from Google:
#
# The model utilises a neural network that is based on sequence-to-sequence models, where it is a type of model that maps the input as a sequence and also outputs a responce in sequence. Additionally, these inputs and outputs can also be translated into other languages. For their work, they had utilised training data of tech support transcripts and movie dialogues.
#
# Below shows some of the responses that was obtained from the published research paper. Source: https://arxiv.org/pdf/1506.05869v1.pdf

# %%
# Neural Conversational Model sample response: Image 1
display(Image(image_path+'Neural Conversational Model sample response 1.png', width=400, unconfined=True))
print('Image ref -> https://arxiv.org/pdf/1506.05869v1.pdf')
# Out:
# Image ref -> https://arxiv.org/pdf/1506.05869v1.pdf

# %%
# Neural Conversational Model sample response: Image 2
display(Image(image_path+'Neural Conversational Model sample response 2.png', width=400, unconfined=True))
print('Image ref -> https://arxiv.org/pdf/1506.05869v1.pdf')
# Out:
# Image ref -> https://arxiv.org/pdf/1506.05869v1.pdf

# %% [markdown]
# After reading the above responses from the machine, it can be easily mistaken as a real human. Note that the model was not explicitly encoded by its maker. Antoher interesting behaviour that the model exhibits is how it uses gender (he, she), places (England) or career (player). These can be seen from the research paper.
#
# ## 4 Building the Chatbot:
#
# Rather than going all out and building a similar chatbot at Google's level, this project will instead try to build the opposite. A chatbot that is so silly that it would be fun and engaging to build.
#
# ## 5 Dataset:
#
# The dataset that will be used as the training data would be derived from real conversations with Cleverbot. The data from the main website cannot be found, but it can be found amongst other github users such as these:
#
# - https://github.com/neyerdav/chatbot
# - https://github.com/GinGin3203/python_chatbot
#
# ## 5.1 Import the required Packages:
